# %% [markdown]
# # Revisiting Copying Algebras

# %%
from finite_algebras import *
import copy

# %%
n = 5
f5 = generate_algebra_mod_n(n)
f5.about(use_table_names=True)
# Out:
# ** Field **
# Name: F5
# Instance ID: 4536820432
# Description: Autogenerated Field of integers mod 5
# Order: 5
# Identity: 'a0'
# Commutative? Yes
# Cyclic?: Yes
#   Generators: ['a1', 'a2', 'a3', 'a4']
# Elements:
#    Index   Name   Inverse  Order
#       0    'a0'    'a0'       1
#       1    'a1'    'a4'       5
#       2    'a2'    'a3'       5
#       3    'a3'    'a2'       5
#       4    'a4'    'a1'       5
# Cayley Table (showing names):
# [['a0', 'a1', 'a2', 'a3', 'a4'],
#  ['a1', 'a2', 'a3', 'a4', 'a0'],
#  ['a2', 'a3', 'a4', 'a0', 'a1'],
#  ['a3', 'a4', 'a0', 'a1', 'a2'],
#  ['a4', 'a0', 'a1', 'a2', 'a3']]
# Mult. Identity: 'a1'
# Mult. Commutative? Yes
# Zero Divisors: None
# Multiplicative Cayley Table (showing names):
# [['a0', 'a0', 'a0', 'a0', 'a0'],
#  ['a0', 'a1', 'a2', 'a3', 'a4'],
#  ['a0', 'a2', 'a4', 'a1', 'a3'],
#  ['a0', 'a3', 'a1', 'a4', 'a2'],
#  ['a0', 'a4', 'a3', 'a2', 'a1']]

# %%
f5x = f5.copy_algebra(['0', '1', '2', '3', '4'], "F5X", "Sawyer's Miniature Arithmetic")

# %%
f5x.about(use_table_names=True)
# Out:
# ** Field **
# Name: F5X
# Instance ID: 4552743504
# Description: Sawyer's Miniature Arithmetic
# Order: 5
# Identity: '0'
# Commutative? Yes
# Cyclic?: Yes
#   Generators: ['1', '2', '3', '4']
# Elements:
#    Index   Name   Inverse  Order
#       0     '0'     '0'       1
#       1     '1'     '4'       5
#       2     '2'     '3'       5
#       3     '3'     '2'       5
#       4     '4'     '1'       5
# Cayley Table (showing names):
# [['0', '1', '2', '3', '4'],
#  ['1', '2', '3', '4', '0'],
#  ['2', '3', '4', '0', '1'],
#  ['3', '4', '0', '1', '2'],
#  ['4', '0', '1', '2', '3']]
# Mult. Identity: '1'
# Mult. Commutative? Yes
# Zero Divisors: None
# Multiplicative Cayley Table (showing names):
# [['0', '0', '0', '0', '0'],
#  ['0', '1', '2', '3', '4'],
#  ['0', '2', '4', '1', '3'],
#  ['0', '3', '1', '4', '2'],
#  ['0', '4', '3', '2', '1']]

# %%
g0 = generate_cyclic_group(7)
g0.about()
# Out:
# ** Group **
# Name: Z7
# Instance ID: 4552744144
# Description: Autogenerated cyclic Group of order 7
# Order: 7
# Identity: 'e'
# Commutative? Yes
# Cyclic?: Yes
#   Generators: ['a', 'a^2', 'a^3', 'a^4', 'a^5', 'a^6']
# Elements:
#    Index   Name   Inverse  Order
#       0     'e'     'e'       1
#       1     'a'   'a^6'       7
#       2   'a^2'   'a^5'       7
#       3   'a^3'   'a^4'       7
#       4   'a^4'   'a^3'       7
#       5   'a^5'   'a^2'       7
#       6   'a^6'     'a'       7
# Cayley Table (showing indices):
# [[0, 1, 2, 3, 4, 5, 6],
#  [1, 2, 3, 4, 5, 6, 0],
#  [2, 3, 4, 5, 6, 0, 1],
#  [3, 4, 5, 6, 0, 1, 2],
#  [4, 5, 6, 0, 1, 2, 3],
#  [5, 6, 0, 1, 2, 3, 4],
#  [6, 0, 1, 2, 3, 4, 5]]

# %%
g0x = g0.copy_algebra()
g0x.about()
# Out:
# ** Group **
# Name: Z7
# Instance ID: 4552744720
# Description: Autogenerated cyclic Group of order 7
# Order: 7
# Identity: 'e'
# Commutative? Yes
# Cyclic?: Yes
#   Generators: ['a', 'a^2', 'a^3', 'a^4', 'a^5', 'a^6']
# Elements:
#    Index   Name   Inverse  Order
#       0     'e'     'e'       1
#       1     'a'   'a^6'       7
#       2   'a^2'   'a^5'       7
#       3   'a^3'   'a^4'       7
#       4   'a^4'   'a^3'       7
#       5   'a^5'   'a^2'       7
#       6   'a^6'     'a'       7
# Cayley Table (showing indices):
# [[0, 1, 2, 3, 4, 5, 6],
#  [1, 2, 3, 4, 5, 6, 0],
#  [2, 3, 4, 5, 6, 0, 1],
#  [3, 4, 5, 6, 0, 1, 2],
#  [4, 5, 6, 0, 1, 2, 3],
#  [5, 6, 0, 1, 2, 3, 4],
#  [6, 0, 1, 2, 3, 4, 5]]
